# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %%
iris = load_iris()
X = iris.data

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_
# Out:
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.show()

# %%
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)
plt.plot(range(1, 11), sse, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()
# Out:
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# F:\anaconda\envs\dpl\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.cluster import AgglomerativeClustering
hierarchical = AgglomerativeClustering(n_clusters=3)
labels_hierarchical = hierarchical.fit_predict(X)

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels_dbscan = dbscan.fit_predict(X)

# %%
silhouette_score(X, labels)
# Out:
# 0.5528190123564095

# %%
silhouette_score(X, labels_hierarchical)
# Out:
# 0.5543236611296419

# %%
silhouette_score(X, labels_dbscan)
# Out:
# 0.48603419703456857

# %%
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
from pylab import mpl
import numpy as np
import datetime 
import warnings
import tensorflow
warnings.filterwarnings('ignore')
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# 创建一个有向图
G = nx.DiGraph()

# 添加节点和边
# 分类算法
G.add_node("分类算法")
G.add_nodes_from([
    "逻辑回归", "决策树", "支持向量机", 
    "K-近邻", "随机森林", "梯度提升树", "神经网络"
])
G.add_edges_from([
    ("分类算法", "逻辑回归"),
    ("分类算法", "决策树"),
    ("分类算法", "支持向量机"),
    ("分类算法", "K-近邻"),
    ("分类算法", "随机森林"),
    ("分类算法", "梯度提升树"),
    ("分类算法", "神经网络")
])

# 评估指标
G.add_node("评估指标")
G.add_nodes_from([
    "准确率", "精确率", "召回率", 
    "F1-score", "ROC曲线", "混淆矩阵"
])
G.add_edges_from([
    ("评估指标", "准确率"),
    ("评估指标", "精确率"),
    ("评估指标", "召回率"),
    ("评估指标", "F1-score"),
    ("评估指标", "ROC曲线"),
    ("评估指标", "混淆矩阵")
])

# 数据预处理
G.add_node("数据预处理")
G.add_nodes_from([
    "数据清洗", "标准化", "缺失值处理", "类别编码"
])
G.add_edges_from([
    ("数据预处理", "数据清洗"),
    ("数据预处理", "标准化"),
    ("数据预处理", "缺失值处理"),
    ("数据预处理", "类别编码")
])

# 特征工程
G.add_node("特征工程")
G.add_nodes_from([
    "特征选择", "特征提取", "特征构造"
])
G.add_edges_from([
    ("特征工程", "特征选择"),
    ("特征工程", "特征提取"),
    ("特征工程", "特征构造")
])

# 模型选择与调优
G.add_node("模型选择与调优")
G.add_nodes_from([
    "交叉验证", "网格搜索", "随机搜索"
])
G.add_edges_from([
    ("模型选择与调优", "交叉验证"),
    ("模型选择与调优", "网格搜索"),
    ("模型选择与调优", "随机搜索")
])

# 可视化知识图谱
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G)  # 使用弹簧布局
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=10, font_color="black", font_weight="bold", arrows=True)
plt.title("机器学习分类知识图谱")
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib import font_manager
import os

# 创建一个有向图
G = nx.DiGraph()

# 添加节点和边
# 关联规则挖掘
G.add_node("关联规则挖掘")
G.add_nodes_from([
    "支持度", "置信度", "提升度", 
    "频繁项集", "Apriori算法", "FP-Growth算法"
])
G.add_edges_from([
    ("关联规则挖掘", "支持度"),
    ("关联规则挖掘", "置信度"),
    ("关联规则挖掘", "提升度"),
    ("关联规则挖掘", "频繁项集"),
    ("关联规则挖掘", "Apriori算法"),
    ("关联规则挖掘", "FP-Growth算法")
])

# 评估指标
G.add_node("评估指标")
G.add_nodes_from([
    "Lift", "支持度阈值", "置信度阈值"
])
G.add_edges_from([
    ("评估指标", "Lift"),
    ("评估指标", "支持度阈值"),
    ("评估指标", "置信度阈值")
])

# 应用领域
G.add_node("应用领域")
G.add_nodes_from([
    "市场篮分析", "推荐系统", "网站导航", "用户行为分析"
])
G.add_edges_from([
    ("应用领域", "市场篮分析"),
    ("应用领域", "推荐系统"),
    ("应用领域", "网站导航"),
    ("应用领域", "用户行为分析")
])

# 可视化知识图谱
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G)  # 使用弹簧布局
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", 
        font_size=10, font_color="black", font_weight="bold", arrows=True,
        font_family='sans-serif')  # 使用中文字体
plt.title("关联规则挖掘知识图谱")  # 设置标题的中文字体
plt.show()
